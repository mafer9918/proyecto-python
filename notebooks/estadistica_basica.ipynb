# %%
import pandas as pd
import matplotlib.pyplot as plt

data_path = "../data/processed/clean_products.csv"
df = pd.read_csv(data_path)

print("Basic Statistics")
print(df.describe())

plt.hist(df["price"], bins=20, edgecolor="black")
plt.title("Distribucion de precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

print("Productos más caros: ")
highestPrice= df.nlargest(5,'price')
print(highestPrice)
# Out:
# Los archivos PNG se guardarán en: c:\Users\ACER\Documents\Tipti\Python\ProyectoFinal\notebooks
# Basic Statistics
#              price  number_reviews      rating
# count   117.000000      117.000000  117.000000
# mean    909.393846        6.897436    2.341880
# std     401.311429        4.255594    1.107672
# min     295.990000        0.000000    1.000000
# 25%     469.100000        3.000000    1.000000
# 50%    1102.660000        7.000000    2.000000
# 75%    1221.580000       10.000000    3.000000
# max    1799.000000       14.000000    4.000000
# Productos más catos:
#                                           title  \
# 28   Asus ROG Strix SCAR Edition GL503VM-ED115T
# 26                Asus ROG Strix GL702ZC-GC154T
# 27                Asus ROG Strix GL702ZC-GC209T
# 25                           Lenovo Legion Y720
# 116               Asus ROG Strix GL702VM-GC146T
#
#                                            description   price  \
# 28   Asus ROG Strix SCAR Edition GL503VM-ED115T, 15...  1799.0
# 26   Asus ROG Strix GL702ZC-GC154T, 17.3" FHD, Ryze...  1769.0
# 27   Asus ROG Strix GL702ZC-GC209T, 17.3" FHD IPS, ...  1769.0
# 25   Lenovo Legion Y720, 15.6" FHD IPS, Core i7-770...  1399.0
# 116  Asus ROG Strix GL702VM-GC146T, 17.3" FHD, Core...  1399.0
#
#      number_reviews  rating
# 28                8       3
# 26                7       4
# 27                8       1
# 25                8       3
# 116              10       3
